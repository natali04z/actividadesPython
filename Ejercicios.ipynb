# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
# Leer la siguiente URL y conocer su informacion principal, mediante el uso los atributos y métodos necesarios de pandas.

# URL
url = "https://raw.githubusercontent.com/rubisabel00/ciencias-de-datos-Sena/main/DocumentosNB03/clientes.csv"

# LEER URL
df_url = pd.read_csv(url)

# INFORMACIÓN
df_url.describe()
# Out:
#        ID del cliente  Frecuencia de compra  Valor promedio de la compra  \
# count      157.000000            157.000000                    152.00000
# mean        82.579618              2.369427                    118.23750
# std         47.555248              1.172804                    249.86509
# min          1.000000              1.000000                     20.00000
# 25%         42.000000              1.000000                     65.20000
# 50%         83.000000              2.000000                     85.10000
# 75%        124.000000              3.000000                    120.28750
# max        161.000000              5.000000                   3110.00000
#
#              Edad
# count  154.000000
# mean    31.233766
# std      9.146443
# min      1.000000
# 25%     26.000000
# 50%     30.000000
# 75%     37.000000
# max     80.000000

# %%
# Realizar una descripcion estadística de la informacion encontrada y normalizarla (Eliminar los null).

df_sin_nulos = df_url.dropna()
df_sin_nulos
# Out:
#      ID del cliente           Nombre Última fecha de compra  \
# 0                 1       Juan Perez             15/03/2022
# 1                 2    Ana Rodriguez             01/04/2022
# 2                 3  Luisa Hernandez             10/12/2021
# 3                 4    Carlos Garcia             28/02/2022
# 4                 5      Maria Gomez             20/03/2022
# ..              ...              ...                    ...
# 152             160      Andrea Soto             09/06/2022
# 153             161  Laura Hernandez             06/06/2022
# 154             145      Luis Garcia             04/06/2022
# 155             154      Luisa Perez             08/06/2022
# 156             160      Andrea Soto             09/06/2022
#
#      Frecuencia de compra  Valor promedio de la compra  \
# 0                       5                        200.5
# 1                       2                         80.0
# 2                       3                        150.2
# 3                       1                        300.0
# 4                       4                         75.8
# ..                    ...                          ...
# 152                     2                         50.0
# 153                     1                        120.0
# 154                     4                         75.2
# 155                     2                         80.0
# 156                     2                         50.0
#
#     Categoría de productos comprados          Método de pago  Edad
# 0                               Ropa      Tarjeta de crédito  32.0
# 1                           Juguetes                Efectivo  45.0
# 2                        Electrónica  Transferencia bancaria  28.0
# 3                          Alimentos      Tarjeta de crédito  50.0
# 4                               Ropa                Efectivo  22.0
# ..                               ...                     ...   ...
# 152                      Electrónica  Transferencia bancaria  25.0
# 153                        Alimentos                Efectivo  39.0
# 154                        Alimentos  Transferencia bancaria  28.0
# 155                             Ropa  Transferencia bancaria  33.0
# 156                      Electrónica  Transferencia bancaria  25.0
#
# [142 rows x 8 columns]

# %%
# Generar una gráfica representativa de la informacion obtenida.

print(df_sin_nulos.plot())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
# Generar dos consultas de agrupamiento de valor agregado a la informacion obtenida.

# Consulta 1
df_sin_nulos.groupby('Método de pago').count()

# Consulta 2
df_sin_nulos.groupby('Método de pago').agg({'Nombre' : "count"})
# Out:
#                         Nombre
# Método de pago
# Efectivo                    50
# Tarjeta de crédito          46
# Transferencia bancaria      46

# %%
# Generar nuevas columnas según sean requeridas para completar la informacion obtenida.

# Nueva columna

df_sin_nulos['Información de pago'] = df_sin_nulos['Nombre'] + " Pago con " + df_sin_nulos['Método de pago']
df_sin_nulos
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_20400\1041582173.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_nulos['Información de pago'] = df_sin_nulos['Nombre'] + " Pago con " + df_sin_nulos['Método de pago']
#      ID del cliente           Nombre Última fecha de compra  \
# 0                 1       Juan Perez             15/03/2022
# 1                 2    Ana Rodriguez             01/04/2022
# 2                 3  Luisa Hernandez             10/12/2021
# 3                 4    Carlos Garcia             28/02/2022
# 4                 5      Maria Gomez             20/03/2022
# ..              ...              ...                    ...
# 152             160      Andrea Soto             09/06/2022
# 153             161  Laura Hernandez             06/06/2022
# 154             145      Luis Garcia             04/06/2022
# 155             154      Luisa Perez             08/06/2022
# 156             160      Andrea Soto             09/06/2022
#
#      Frecuencia de compra  Valor promedio de la compra  \
# 0                       5                        200.5
# 1                       2                         80.0
# 2                       3                        150.2
# 3                       1                        300.0
# 4                       4                         75.8
# ..                    ...                          ...
# 152                     2                         50.0
# 153                     1                        120.0
# 154                     4                         75.2
# 155                     2                         80.0
# 156                     2                         50.0
#
#     Categoría de productos comprados          Método de pago  Edad  \
# 0                               Ropa      Tarjeta de crédito  32.0
# 1                           Juguetes                Efectivo  45.0
# 2                        Electrónica  Transferencia bancaria  28.0
# 3                          Alimentos      Tarjeta de crédito  50.0
# 4                               Ropa                Efectivo  22.0
# ..                               ...                     ...   ...
# 152                      Electrónica  Transferencia bancaria  25.0
# 153                        Alimentos                Efectivo  39.0
# 154                        Alimentos  Transferencia bancaria  28.0
# 155                             Ropa  Transferencia bancaria  33.0
# 156                      Electrónica  Transferencia bancaria  25.0
#
#                                  Información de pago
# 0             Juan Perez Pago con Tarjeta de crédito
# 1                    Ana Rodriguez Pago con Efectivo
# 2    Luisa Hernandez Pago con Transferencia bancaria
# 3          Carlos Garcia Pago con Tarjeta de crédito
# 4                      Maria Gomez Pago con Efectivo
# ..                                               ...
# 152      Andrea Soto Pago con Transferencia bancaria
# 153                Laura Hernandez Pago con Efectivo
# 154      Luis Garcia Pago con Transferencia bancaria
# 155      Luisa Perez Pago con Transferencia bancaria
# 156      Andrea Soto Pago con Transferencia bancaria
#
# [142 rows x 9 columns]

# %%
# Exportar el trabajo realizado en los anteriores items a un archivo de excel.

df_sin_nulos.to_excel("clientes.xlsx", index=False)
df_to_excel = pd.read_excel("clientes.xlsx")
df_to_excel
# Out:
#      ID del cliente           Nombre Última fecha de compra  \
# 0                 1       Juan Perez             15/03/2022
# 1                 2    Ana Rodriguez             01/04/2022
# 2                 3  Luisa Hernandez             10/12/2021
# 3                 4    Carlos Garcia             28/02/2022
# 4                 5      Maria Gomez             20/03/2022
# ..              ...              ...                    ...
# 137             160      Andrea Soto             09/06/2022
# 138             161  Laura Hernandez             06/06/2022
# 139             145      Luis Garcia             04/06/2022
# 140             154      Luisa Perez             08/06/2022
# 141             160      Andrea Soto             09/06/2022
#
#      Frecuencia de compra  Valor promedio de la compra  \
# 0                       5                        200.5
# 1                       2                         80.0
# 2                       3                        150.2
# 3                       1                        300.0
# 4                       4                         75.8
# ..                    ...                          ...
# 137                     2                         50.0
# 138                     1                        120.0
# 139                     4                         75.2
# 140                     2                         80.0
# 141                     2                         50.0
#
#     Categoría de productos comprados          Método de pago  Edad  \
# 0                               Ropa      Tarjeta de crédito    32
# 1                           Juguetes                Efectivo    45
# 2                        Electrónica  Transferencia bancaria    28
# 3                          Alimentos      Tarjeta de crédito    50
# 4                               Ropa                Efectivo    22
# ..                               ...                     ...   ...
# 137                      Electrónica  Transferencia bancaria    25
# 138                        Alimentos                Efectivo    39
# 139                        Alimentos  Transferencia bancaria    28
# 140                             Ropa  Transferencia bancaria    33
# 141                      Electrónica  Transferencia bancaria    25
#
#                                  Información de pago
# 0             Juan Perez Pago con Tarjeta de crédito
# 1                    Ana Rodriguez Pago con Efectivo
# 2    Luisa Hernandez Pago con Transferencia bancaria
# 3          Carlos Garcia Pago con Tarjeta de crédito
# 4                      Maria Gomez Pago con Efectivo
# ..                                               ...
# 137      Andrea Soto Pago con Transferencia bancaria
# 138                Laura Hernandez Pago con Efectivo
# 139      Luis Garcia Pago con Transferencia bancaria
# 140      Luisa Perez Pago con Transferencia bancaria
# 141      Andrea Soto Pago con Transferencia bancaria
#
# [142 rows x 9 columns]
